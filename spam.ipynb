# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushree-5-prog/NM/blob/main/spam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install transformers gradio torch

import gradio as gr
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# Load pre-trained model and tokenizer
model_name = "distilbert-base-uncased-finetuned-sst-2-english"  # Pre-trained model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Function to predict spam or not spam
def predict_spam(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
        prediction = torch.argmax(outputs.logits, dim=1).item()

    return "Spam" if prediction == 1 else "Not Spam"

# Create Gradio interface
iface = gr.Interface(
    fn=predict_spam,
    inputs=gr.Textbox(lines=3, placeholder="Enter your message..."),
    outputs="text",
    title="Spam Detector using Transformers",
    description="Enter a text message to check if it is spam or not using a transformer model."
)

# Launch the Gradio app
iface.launch(share=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/27/94/3266821f65b92b3138631e9c8e7fe1fb513804ac934485a8d05776e1dd43/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl
# ...

# %%
# Install required libraries
# !pip install TTS gradio torch

import torch
import gradio as gr
from TTS.api import TTS

# Load an open-source TTS model (FastSpeech2)
tts_model = TTS("tts_models/en/ljspeech/fast_pitch").to("cpu")  # Use "cuda" if GPU is available

# Function to generate speech from text
def text_to_speech(text):
    output_path = "output.wav"
    tts_model.tts_to_file(text=text, file_path=output_path)
    return output_path

# Gradio interface
iface = gr.Interface(
    fn=text_to_speech,
    inputs=gr.Textbox(lines=3, placeholder="Enter text..."),
    outputs=gr.Audio(type="file"),
    title="Text-to-Speech (TTS)",
    description="Enter text and listen to the generated speech using an open-source model."
)

# Launch the Gradio app
iface.launch(share=True)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 41.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 53.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 27.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 35.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 77.1 MB/s eta 0:00:00
# ...

# %%
# Install dependencies without breaking Colab's environment
# !pip install torch gradio
# !pip install TTS --no-deps  # Install TTS without conflicting dependencies

import torch
import gradio as gr
from TTS.api import TTS

# Load an open-source TTS model
tts_model = TTS("tts_models/en/ljspeech/fast_pitch").to("cpu")  # Change to "cuda" if using GPU

# Function to generate speech from text
def text_to_speech(text):
    output_path = "output.wav"
    tts_model.tts_to_file(text=text, file_path=output_path)
    return output_path

# Create Gradio interface
iface = gr.Interface(
    fn=text_to_speech,
    inputs=gr.Textbox(lines=3, placeholder="Enter text..."),
    outputs=gr.Audio(type="file"),
    title="Text-to-Speech (TTS)",
    description="Enter text and listen to the generated speech using an open-source model."
)

# Launch Gradio app
iface.launch(share=True)
# Out:
# ...
#  > Downloading model to /root/.local/share/tts/tts_models--en--ljspeech--fast_pitch
#  99%|█████████▉| 454M/458M [00:05<00:00, 67.7MiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Downloading model to /root/.local/share/tts/vocoder_models--en--ljspeech--hifigan_v2
# 100%|██████████| 458M/458M [00:14<00:00, 31.9MiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Using model: fast_pitch
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
# ...

# %%
# Install dependencies
# !pip install gtts gradio

import gradio as gr
from gtts import gTTS
import os

# Function to generate speech from text
def text_to_speech(text):
    output_path = "output.mp3"
    tts = gTTS(text=text, lang="en")  # Set language (e.g., 'en' for English)
    tts.save(output_path)
    return output_path

# Create Gradio interface
iface = gr.Interface(
    fn=text_to_speech,
    inputs=gr.Textbox(lines=3, placeholder="Enter text..."),
    outputs=gr.Audio(type="filepath"),  # Returns file path for Gradio
    title="Text-to-Speech (TTS) using gTTS",
    description="Enter text and listen to the generated speech using Google Text-to-Speech (gTTS)."
)

# Launch Gradio app
iface.launch(share=True)
# Out:
# ...
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://dbe30c31b50e0c8a8b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dbe30c31b50e0c8a8b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
